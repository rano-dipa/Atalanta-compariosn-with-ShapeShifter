# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install dask[dataframe]
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.10/dist-packages (2024.10.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.5.0)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2.2.2)
# Collecting dask-expr<1.2,>=1.1 (from dask[dataframe])
#   Downloading dask_expr-1.1.19-py3-none-any.whl.metadata (2.6 kB)
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
#   Downloading dask_expr-1.1.18-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.16-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.10/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (17.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2024.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.16.0)
# Downloading dask_expr-1.1.16-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: dask-expr
# Successfully installed dask-expr-1.1.16

# %%
import numpy as np
import pandas as pd
import os
import dask.dataframe as dd
import csv
from tabulate import tabulate
import numpy as np
import random
import time


def main():

    def filename_to_key(filename):
        # Remove the prefix and suffix
        base_name = filename.removeprefix("pt_").removesuffix(".csv")
        # Split the remaining part into components
        #parts = base_name.split("_")
        return base_name

    def csv_to_dict(csv_path):
        # Load the CSV into a DataFrame
        df = pd.read_csv(csv_path)
        # Convert the DataFrame to a list of dictionaries
        data_dict = df.to_dict(orient='records')
        return data_dict

    def add_row_to_csv(row, output_file):
        # Append the row to the file
        with open(output_file, mode='a', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=['Model_Name', 'Layer', 'Type', 'Encoded_Stream'])
            writer.writerow(row)

    def print_encoded_summary_table(summary_table):

        # Convert rows to tabulate format
        table = [list(row.values()) for row in summary_table]
        headers = summary_table[0].keys()  # Use keys of the first row as headers

        # Pretty-print the table
        print(tabulate(table, headers=headers, tablefmt="grid"))

    def output_summary_to_csv(csv_table, output_file):

        # Write to the CSV file
        with open(output_file, mode='w', newline='') as file:
            # Create a CSV DictWriter object
            writer = csv.DictWriter(file, fieldnames=csv_table[0].keys())

            # Write the header row
            writer.writeheader()

            # Write each row
            for row in csv_table:
                writer.writerow(row)

        print(f"Data has been written to {output_file}")

    # ShapeShifter encoding function
    def shapeshifter_encode(data, group_size=16):
        encoded_data = []
        encoded_size = 0
        for i in range(0, len(data), group_size):
            group = data[i:i+group_size]
            max_val = np.max(np.abs(group))
            bits_needed = int(np.ceil(np.log2(max_val + 1))) if max_val > 0 else 0
            encoded_data.append((bits_needed, group.tolist()))
            encoded_size += bits_needed * len(group)
        return encoded_data, encoded_size



    weights_csv_path = '/content/drive/MyDrive/CSCE_614/Project/weights_all_layers.csv'
    act_csv_path = '/content/drive/MyDrive/CSCE_614/Project/activations_all_layers.csv'

    # Output file paths
    weights_encoded_output_file = '/content/drive/MyDrive/CSCE_614/Project/shapeshifter_outputs/shapeshifter_encoded_output_weights.csv'
    act_encoded_output_file = '/content/drive/MyDrive/CSCE_614/Project/shapeshifter_outputs/shapeshifter_encoded_output_activations.csv'

    # Output CSV file paths
    weights_summary_file = '/content/drive/MyDrive/CSCE_614/Project/shapeshifter_outputs/shapeshifter_encoded_summary_weights.csv'
    act_summary_file = '/content/drive/MyDrive/CSCE_614/Project/shapeshifter_outputs/shapeshifter_encoded_summary_activations.csv'

    file_path_dict = {
    'weights' : {'input_stream': weights_csv_path, 'encoded_output': weights_encoded_output_file, 'encoded_summary': weights_summary_file},
    'activaitions' : {'input_stream': act_csv_path, 'encoded_output': act_encoded_output_file, 'encoded_summary': act_summary_file},
    }

    for vtype in file_path_dict.keys():
        values_csv_path = file_path_dict[vtype]['input_stream']
        encoded_output_file = file_path_dict[vtype]['encoded_output']
        csv_summary_file = file_path_dict[vtype]['encoded_summary']

        # Write the header row (only once)
        with open(encoded_output_file, mode='w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=['Model_Name', 'Layer', 'Type', 'Encoded_Stream'])
            writer.writeheader()

        summary_table = []
        csv_file_out = []

        # Process CSV line by line
        with open(values_csv_path, 'r') as csvfile:
            csvreader = csv.reader(csvfile)
            headers = next(csvreader)  # Read header row

            for row_data in csvreader:
                try:
                    row = {'Model Name':row_data[0] , 'Layer Number':row_data[1], 'Type':row_data[2]}

                    # Extract numeric values after the first three columns
                    input_array = np.array(row_data[3:], dtype=np.uint8)


                    # encode using Atalanta Encoder
                    encoded_stream, encoded_size = shapeshifter_encode(input_array)

                    output_row = {
                        'Model_Name': row['Model Name'],
                        'Layer': row['Layer Number'],
                        'Type': row['Type'],
                        'Encoded_Stream': encoded_stream,
                    }

                    # Append the row to the CSV file
                    add_row_to_csv(output_row, encoded_output_file)

                    input_stream_length = len(input_array)
                    input_stream_length_bits = input_stream_length*8
                    encoded_stream_length = encoded_size
                    compression_ratio = (input_stream_length_bits)/encoded_stream_length
                    compression_percentage = (1-(1/compression_ratio))*100



                    output_summary = {
                        'Model_Name': row['Model Name'],
                        'Layer_Number': row['Layer Number'],
                        'Type': row['Type'],
                        'Input_Stream_Length (values)': input_stream_length,
                        'Original_Length (bits)': input_stream_length_bits,
                        'After Compression (bits)': encoded_stream_length,
                        'Compression_Ratio': compression_ratio,
                        'Compression_Percentage': compression_percentage
                        }

                    summary_table.append(output_summary)

                    csv_summary = {
                        'Model_Name': row['Model Name'],
                        'Layer_Number': row['Layer Number'],
                        'Type': row['Type'],
                        'Input_Stream_Length (values)': input_stream_length,
                        'Original (bits)': input_stream_length_bits,
                        'After Compression (bits)': encoded_stream_length,
                        'Compression_Ratio': compression_ratio,
                        'Compression_Percentage': compression_percentage
                        }

                    csv_file_out.append(csv_summary)
                except Exception as e:
                    print(f"Error processing row: {e}")
                    continue


        # Print the summary table
        print_encoded_summary_table(summary_table)
        output_summary_to_csv(csv_file_out, csv_summary_file)

if __name__ == "__main__":
    main()
# Out:
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Model_Name   | Layer_Number                      | Type    |   Input_Stream_Length (values) |   Original_Length (bits) |   After Compression (bits) |   Compression_Ratio |   Compression_Percentage |
# +==============+===================================+=========+================================+==========================+============================+=====================+==========================+
# | Resnet50     | conv1.weight                      | weights |                           9408 |                    75264 |                      75248 |             1.00021 |              0.0212585   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.0.conv1.weight             | weights |                           4096 |                    32768 |                      32768 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.0.conv2.weight             | weights |                          36864 |                   294912 |                     294832 |             1.00027 |              0.0271267   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.0.conv3.weight             | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.0.downsample.0.weight      | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.1.conv1.weight             | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.1.conv2.weight             | weights |                          36864 |                   294912 |                     294912 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.1.conv3.weight             | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.2.conv1.weight             | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.2.conv2.weight             | weights |                          36864 |                   294912 |                     294896 |             1.00005 |              0.00542535  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer1.2.conv3.weight             | weights |                          16384 |                   131072 |                     131072 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.0.conv1.weight             | weights |                          32768 |                   262144 |                     262144 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.0.conv2.weight             | weights |                         147456 |                  1179648 |                    1177728 |             1.00163 |              0.16276     |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.0.conv3.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.0.downsample.0.weight      | weights |                         131072 |                  1048576 |                    1048576 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.1.conv1.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.1.conv2.weight             | weights |                         147456 |                  1179648 |                    1179328 |             1.00027 |              0.0271267   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.1.conv3.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.2.conv1.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.2.conv2.weight             | weights |                         147456 |                  1179648 |                    1179440 |             1.00018 |              0.0176324   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.2.conv3.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.3.conv1.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.3.conv2.weight             | weights |                         147456 |                  1179648 |                    1179440 |             1.00018 |              0.0176324   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer2.3.conv3.weight             | weights |                          65536 |                   524288 |                     524288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.0.conv1.weight             | weights |                         131072 |                  1048576 |                    1048576 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.0.conv2.weight             | weights |                         589824 |                  4718592 |                    4703504 |             1.00321 |              0.319756    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.0.conv3.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.0.downsample.0.weight      | weights |                         524288 |                  4194304 |                    4194304 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.1.conv1.weight             | weights |                         262144 |                  2097152 |                    2097136 |             1.00001 |              0.000762939 |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.1.conv2.weight             | weights |                         589824 |                  4718592 |                    4714528 |             1.00086 |              0.0861274   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.1.conv3.weight             | weights |                         262144 |                  2097152 |                    2097120 |             1.00002 |              0.00152588  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.2.conv1.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.2.conv2.weight             | weights |                         589824 |                  4718592 |                    4716928 |             1.00035 |              0.0352648   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.2.conv3.weight             | weights |                         262144 |                  2097152 |                    2097136 |             1.00001 |              0.000762939 |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.3.conv1.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.3.conv2.weight             | weights |                         589824 |                  4718592 |                    4717504 |             1.00023 |              0.0230577   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.3.conv3.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.4.conv1.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.4.conv2.weight             | weights |                         589824 |                  4718592 |                    4715472 |             1.00066 |              0.0661214   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.4.conv3.weight             | weights |                         262144 |                  2097152 |                    2097136 |             1.00001 |              0.000762939 |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.5.conv1.weight             | weights |                         262144 |                  2097152 |                    2097152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.5.conv2.weight             | weights |                         589824 |                  4718592 |                    4711632 |             1.00148 |              0.147502    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer3.5.conv3.weight             | weights |                         262144 |                  2097152 |                    2097120 |             1.00002 |              0.00152588  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.0.conv1.weight             | weights |                         524288 |                  4194304 |                    4194304 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.0.conv2.weight             | weights |                        2359296 |                 18874368 |                   18756624 |             1.00628 |              0.62383     |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.0.conv3.weight             | weights |                        1048576 |                  8388608 |                    8388496 |             1.00001 |              0.00133514  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.0.downsample.0.weight      | weights |                        2097152 |                 16777216 |                   16777168 |             1       |              0.000286102 |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.1.conv1.weight             | weights |                        1048576 |                  8388608 |                    8388528 |             1.00001 |              0.000953674 |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.1.conv2.weight             | weights |                        2359296 |                 18874368 |                   18824880 |             1.00263 |              0.262197    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.1.conv3.weight             | weights |                        1048576 |                  8388608 |                    8388480 |             1.00002 |              0.00152588  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.2.conv1.weight             | weights |                        1048576 |                  8388608 |                    8388480 |             1.00002 |              0.00152588  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.2.conv2.weight             | weights |                        2359296 |                 18874368 |                   18773840 |             1.00535 |              0.532617    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Resnet50     | layer4.2.conv3.weight             | weights |                        1048576 |                  8388608 |                    8388480 |             1.00002 |              0.00152588  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.0.0.weight               | weights |                            864 |                     6912 |                       6912 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.1.conv.0.0.weight        | weights |                            288 |                     2304 |                       2304 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.1.conv.1.weight          | weights |                            512 |                     4096 |                       4096 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.2.conv.0.0.weight        | weights |                           1536 |                    12288 |                      12288 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.2.conv.1.0.weight        | weights |                            864 |                     6912 |                       6912 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.2.conv.2.weight          | weights |                           2304 |                    18432 |                      18432 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.3.conv.0.0.weight        | weights |                           3456 |                    27648 |                      27648 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.3.conv.1.0.weight        | weights |                           1296 |                    10368 |                      10368 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.3.conv.2.weight          | weights |                           3456 |                    27648 |                      27648 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.4.conv.0.0.weight        | weights |                           3456 |                    27648 |                      27648 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.4.conv.1.0.weight        | weights |                           1296 |                    10368 |                      10336 |             1.0031  |              0.308642    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.4.conv.2.weight          | weights |                           4608 |                    36864 |                      36864 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.5.conv.0.0.weight        | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.5.conv.1.0.weight        | weights |                           1728 |                    13824 |                      13824 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.5.conv.2.weight          | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.6.conv.0.0.weight        | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.6.conv.1.0.weight        | weights |                           1728 |                    13824 |                      13824 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.6.conv.2.weight          | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.7.conv.0.0.weight        | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.7.conv.1.0.weight        | weights |                           1728 |                    13824 |                      13568 |             1.01887 |              1.85185     |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.7.conv.2.weight          | weights |                          12288 |                    98304 |                      98304 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.8.conv.0.0.weight        | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.8.conv.1.0.weight        | weights |                           3456 |                    27648 |                      27632 |             1.00058 |              0.0578704   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.8.conv.2.weight          | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.9.conv.0.0.weight        | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.9.conv.1.0.weight        | weights |                           3456 |                    27648 |                      27648 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.9.conv.2.weight          | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.10.conv.0.0.weight       | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.10.conv.1.0.weight       | weights |                           3456 |                    27648 |                      27632 |             1.00058 |              0.0578704   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.10.conv.2.weight         | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.11.conv.0.0.weight       | weights |                          24576 |                   196608 |                     196608 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.11.conv.1.0.weight       | weights |                           3456 |                    27648 |                      27600 |             1.00174 |              0.173611    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.11.conv.2.weight         | weights |                          36864 |                   294912 |                     294912 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.12.conv.0.0.weight       | weights |                          55296 |                   442368 |                     442368 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.12.conv.1.0.weight       | weights |                           5184 |                    41472 |                      41376 |             1.00232 |              0.231481    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.12.conv.2.weight         | weights |                          55296 |                   442368 |                     442368 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.13.conv.0.0.weight       | weights |                          55296 |                   442368 |                     442368 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.13.conv.1.0.weight       | weights |                           5184 |                    41472 |                      41296 |             1.00426 |              0.424383    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.13.conv.2.weight         | weights |                          55296 |                   442368 |                     442368 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.14.conv.0.0.weight       | weights |                          55296 |                   442368 |                     442352 |             1.00004 |              0.0036169   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.14.conv.1.0.weight       | weights |                           5184 |                    41472 |                      41008 |             1.01131 |              1.11883     |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.14.conv.2.weight         | weights |                          92160 |                   737280 |                     737280 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.15.conv.0.0.weight       | weights |                         153600 |                  1228800 |                    1228800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.15.conv.1.0.weight       | weights |                           8640 |                    69120 |                      68688 |             1.00629 |              0.625       |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.15.conv.2.weight         | weights |                         153600 |                  1228800 |                    1228800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.16.conv.0.0.weight       | weights |                         153600 |                  1228800 |                    1228800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.16.conv.1.0.weight       | weights |                           8640 |                    69120 |                      68592 |             1.0077  |              0.763889    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.16.conv.2.weight         | weights |                         153600 |                  1228800 |                    1228800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.17.conv.0.0.weight       | weights |                         153600 |                  1228800 |                    1228800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.17.conv.1.0.weight       | weights |                           8640 |                    69120 |                      68240 |             1.0129  |              1.27315     |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.17.conv.2.weight         | weights |                         307200 |                  2457600 |                    2457600 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | Mobilenet_v2 | features.18.0.weight              | weights |                         409600 |                  3276800 |                    3276800 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | conv1.conv.weight                 | weights |                           9408 |                    75264 |                      74928 |             1.00448 |              0.446429    |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | conv2.conv.weight                 | weights |                           4096 |                    32768 |                      32768 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | conv3.conv.weight                 | weights |                         110592 |                   884736 |                     884400 |             1.00038 |              0.0379774   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch1.conv.weight   | weights |                          12288 |                    98304 |                      98304 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch2.0.conv.weight | weights |                          18432 |                   147456 |                     147456 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch2.1.conv.weight | weights |                         110592 |                   884736 |                     884656 |             1.00009 |              0.00904225  |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch3.0.conv.weight | weights |                           3072 |                    24576 |                      24576 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch3.1.conv.weight | weights |                           4608 |                    36864 |                      36864 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3a.branch4.1.conv.weight | weights |                           6144 |                    49152 |                      49152 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3b.branch1.conv.weight   | weights |                          32768 |                   262144 |                     262144 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3b.branch2.0.conv.weight | weights |                          32768 |                   262144 |                     262144 |             1       |              0           |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3b.branch2.1.conv.weight | weights |                         221184 |                  1769472 |                    1769168 |             1.00017 |              0.0171803   |
# +--------------+-----------------------------------+---------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | inception3b.branch3.0.conv.weight | weights |                           8192 |                    65536 |                      65536 |             1       |              0           |
# ...
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(512, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.03549756109714508, zero_point=0)                               | activations |                         125440 |                  1003520 |                     488096 |             2.05599 |              51.3616     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(512, 112, kernel_size=(1, 1), stride=(1, 1), scale=0.05736524611711502, zero_point=0)                              | activations |                         219520 |                  1756160 |                     935648 |             1.87695 |              46.7219     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(512, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.0540192648768425, zero_point=0)                               | activations |                         282240 |                  2257920 |                    1191648 |             1.89479 |              47.2236     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(144, 288, kernel_size=(3, 3), stride=(1, 1), scale=0.05020187795162201, zero_point=0, padding=(1, 1))              | activations |                         564480 |                  4515840 |                    1936240 |             2.33227 |              57.1234     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(512, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.053172893822193146, zero_point=0)                              | activations |                          62720 |                   501760 |                     303728 |             1.652   |              39.4675     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(32, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.039254166185855865, zero_point=0, padding=(1, 1))               | activations |                         125440 |                  1003520 |                     520304 |             1.92872 |              48.1521     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(512, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.032393332570791245, zero_point=0)                              | activations |                         125440 |                  1003520 |                     486480 |             2.06282 |              51.5226     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(528, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.035852935165166855, zero_point=0)                             | activations |                         501760 |                  4014080 |                    1014624 |             3.95622 |              74.7234     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(528, 160, kernel_size=(1, 1), stride=(1, 1), scale=0.048804812133312225, zero_point=0)                             | activations |                         313600 |                  2508800 |                    1204272 |             2.08325 |              51.9981     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(160, 320, kernel_size=(3, 3), stride=(1, 1), scale=0.04531234875321388, zero_point=0, padding=(1, 1))              | activations |                         627200 |                  5017600 |                     921680 |             5.44397 |              81.6311     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(528, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.08282043784856796, zero_point=0)                               | activations |                          62720 |                   501760 |                     298592 |             1.68042 |              40.4911     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(32, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.04102787747979164, zero_point=0, padding=(1, 1))               | activations |                         250880 |                  2007040 |                     565600 |             3.54851 |              71.8192     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(528, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.03729861229658127, zero_point=0)                              | activations |                         250880 |                  2007040 |                     622624 |             3.22352 |              68.978      |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.052909042686223984, zero_point=0)                             | activations |                         125440 |                  1003520 |                     307984 |             3.25835 |              69.3096     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 160, kernel_size=(1, 1), stride=(1, 1), scale=0.06558413803577423, zero_point=0)                              | activations |                          78400 |                   627200 |                     300816 |             2.085   |              52.0383     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(160, 320, kernel_size=(3, 3), stride=(1, 1), scale=0.05044007673859596, zero_point=0, padding=(1, 1))              | activations |                         156800 |                  1254400 |                     409408 |             3.06394 |              67.3622     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.07183368504047394, zero_point=0)                               | activations |                          15680 |                   125440 |                      79792 |             1.57209 |              36.3903     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(32, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.03908950462937355, zero_point=0, padding=(1, 1))               | activations |                          62720 |                   501760 |                     145440 |             3.44994 |              71.014      |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.03237222880125046, zero_point=0)                              | activations |                          62720 |                   501760 |                     224816 |             2.23187 |              55.1945     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 384, kernel_size=(1, 1), stride=(1, 1), scale=0.0696367397904396, zero_point=0)                               | activations |                         188160 |                  1505280 |                     739728 |             2.03491 |              50.8578     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 192, kernel_size=(1, 1), stride=(1, 1), scale=0.0714770182967186, zero_point=0)                               | activations |                          94080 |                   752640 |                     223232 |             3.37156 |              70.3401     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(192, 384, kernel_size=(3, 3), stride=(1, 1), scale=0.0846027359366417, zero_point=0, padding=(1, 1))               | activations |                         188160 |                  1505280 |                     598224 |             2.51625 |              60.2583     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 48, kernel_size=(1, 1), stride=(1, 1), scale=0.07058058679103851, zero_point=0)                               | activations |                          23520 |                   188160 |                      63104 |             2.98174 |              66.4626     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(48, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.0835314691066742, zero_point=0, padding=(1, 1))                | activations |                          62720 |                   501760 |                     184352 |             2.72175 |              63.2589     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# | GoogLeNet    | QuantizedConvReLU2d(832, 128, kernel_size=(1, 1), stride=(1, 1), scale=0.05553031340241432, zero_point=0)                              | activations |                          62720 |                   501760 |                     234240 |             2.14208 |              53.3163     |
# +--------------+----------------------------------------------------------------------------------------------------------------------------------------+-------------+--------------------------------+--------------------------+----------------------------+---------------------+--------------------------+
# Data has been written to /content/drive/MyDrive/CSCE_614/Project/shapeshifter_outputs/shapeshifter_encoded_summary_activations.csv
